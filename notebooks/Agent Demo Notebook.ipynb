# %% [markdown]
# # Agent Demo Notebook
#
# Create a small sample sales dataframe for quick Fabric notebook demos.

# %%
import pandas as pd

sales_data = [
    {"order_id": 1001, "region": "North", "product": "Widget", "quantity": 4, "unit_price": 25.00},
    {"order_id": 1002, "region": "South", "product": "Gadget", "quantity": 2, "unit_price": 40.00},
    {"order_id": 1003, "region": "West", "product": "Widget", "quantity": 6, "unit_price": 25.00}
]

sales_df = pd.DataFrame(sales_data)
sales_df["sales_amount"] = sales_df["quantity"] * sales_df["unit_price"]

display(sales_df)
